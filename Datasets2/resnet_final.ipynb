# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torchvision.datasets as datasets
from torchvision.datasets import ImageFolder
from math import ceil
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,recall_score,precision_score,confusion_matrix,f1_score,ConfusionMatrixDisplay,classification_report

# %%
def list_files(dir):
    file_list = []
    for root, dirs, files in os.walk(dir):
        for file in files:
            if file.endswith(".png"):
                file_list.append(os.path.join(root, file))
    return file_list

# %%
data_dir = '/content/drive/MyDrive/DATA'


output_dir = '/content/drive/MyDrive/DATA'


train_val_split = 0.8
val_split = 0.1


for class_dir in os.listdir(data_dir):

    class_path = os.path.join(data_dir, class_dir)


    if not os.path.isdir(class_path):
        continue

    print(f"Processing {class_dir} class...")


    files = list_files(class_path)


    random.shuffle(files)


    num_train_val_files = int(train_val_split * len(files))
    num_val_files = int(val_split * num_train_val_files)

    train_val_files = files[:num_train_val_files]
    train_files = train_val_files[:-num_val_files]
    val_files = train_val_files[-num_val_files:]
    test_files = files[num_train_val_files:]


    train_class_dir = os.path.join(output_dir, 'train', class_dir)
    val_class_dir = os.path.join(output_dir, 'val', class_dir)
    test_class_dir = os.path.join(output_dir, 'test', class_dir)
    os.makedirs(train_class_dir, exist_ok=True)
    os.makedirs(val_class_dir, exist_ok=True)
    os.makedirs(test_class_dir, exist_ok=True)


    for file_path in train_files:
        file_name = os.path.basename(file_path)
        dst = os.path.join(train_class_dir, file_name)
        shutil.copy(file_path, dst)


    for file_path in val_files:
        file_name = os.path.basename(file_path)
        dst = os.path.join(val_class_dir, file_name)
        shutil.copy(file_path, dst)


    for file_path in test_files:
        file_name = os.path.basename(file_path)
        dst = os.path.join(test_class_dir, file_name)
        shutil.copy(file_path, dst)

print("Data split completed successfully.")
# Out:
# Processing 54 class...
# Processing 5 class...
# Processing 3 class...
# Processing 55 class...
# Processing 56 class...
# Processing 35 class...
# Processing 57 class...
# Processing 7 class...
# Processing 4 class...
# Processing 30 class...
# Processing 0 class...
# Processing 26 class...
# Processing 16 class...
# Processing 11 class...
# Processing 24 class...
# Processing 10 class...
# Processing 28 class...
# Processing 17 class...
# Processing 14 class...
# Processing 12 class...
# Data split completed successfully.

# %%
class RoadSignDataset(Dataset):
    def __init__(self, root_dir, split="train", transform=None):
        self.root_dir = os.path.join(root_dir, split)
        self.transform = transform


        self.class_names = sorted(os.listdir(self.root_dir))


        self.image_paths = []
        self.labels = []


        for label_idx, class_name in enumerate(self.class_names):
            class_dir = os.path.join(self.root_dir, class_name)


            image_files = [f for f in os.listdir(class_dir) if f.endswith('.png')]


            self.image_paths.extend([os.path.join(class_dir, img) for img in image_files])
            self.labels.extend([label_idx] * len(image_files))

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

dataset_root = '/content/drive/MyDrive/DATA'
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])
train_dataset = RoadSignDataset(root_dir=dataset_root, split='train', transform=transform)
test_dataset = RoadSignDataset(root_dir=dataset_root, split='test', transform=transform)
val_dataset = RoadSignDataset(root_dir=dataset_root, split='val', transform=transform)

def get_data_loader(dataset,batch_size,shuffle):
  return DataLoader(dataset,batch_size=batch_size,shuffle=shuffle)

# %%
# Out:
# Mounted at /content/drive

# %%
# Training and evaluation
def train(num_epochs, model, train_loader, val_loader, criterion, optimizer, patience=5):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    total_steps = len(train_loader)

    train_loss = []
    train_accuracy = []
    val_loss = []
    val_accuracy = []

    max_loss = float('inf')
    epoch_change = 0

    for epoch in range(num_epochs):
        losses_train = 0
        total_train = 0
        correct_train = 0

        model.train()
        for i, data in enumerate(train_loader):
            images, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            losses_train += loss.item()
            total_train += labels.size(0)
            _, predicted = torch.max(outputs.data, 1)
            correct_train += (predicted == labels).sum().item()

        mean_loss_epoch = losses_train / total_steps
        train_loss.append(mean_loss_epoch)
        train_accuracy.append((correct_train / total_train) * 100)

        model.eval()
        losses_val = 0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for i, data in enumerate(val_loader):
                images_val, labels_val = data[0].to(device), data[1].to(device)
                outputs_val = model(images_val)
                loss_val = criterion(outputs_val, labels_val)
                losses_val += loss_val.item()
                _, predicted = torch.max(outputs_val.data, 1)
                correct_val += (predicted == labels_val).sum().item()
                total_val += labels_val.size(0)

        val_epoch_loss = losses_val / len(val_loader)
        val_loss.append(val_epoch_loss)
        val_accuracy.append((correct_val / total_val) * 100)

        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {mean_loss_epoch:.4f}, Accuracy: {(correct_train / total_train) * 100:.2f}%, Val Loss: {val_epoch_loss:.4f}, Val Accuracy: {(correct_val / total_val) * 100:.2f}%')

        if val_epoch_loss < max_loss:
            max_loss = val_epoch_loss
            epoch_change = 0
        else:
            epoch_change += 1

        if epoch_change >= patience:
            print(f'Early stop after {epoch+1} epochs')
            break

    return train_loss, train_accuracy, val_accuracy, model,val_loss

# %%
# Evaluate the model on test set
def test(model, test_loader):
	model.eval()
	device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
	print("Device: {}".format(device))
	torch.cuda.empty_cache()
	model.to(device)
	test_preds = []
	test_labels = []
	with torch.no_grad():
		for images, labels in test_loader:
			images, labels = images.to(device), labels.to(device)
			outputs = model(images)
			_, predicted = torch.max(outputs, 1)
			test_preds.extend(predicted.cpu().numpy())
			test_labels.extend(labels.cpu().numpy())

			test_accuracy = accuracy_score(test_labels, test_preds)
			test_recall = recall_score(test_labels, test_preds,average='micro')
			test_f1score = f1_score(test_labels, test_preds,average='micro')
			test_precision=precision_score(test_labels, test_preds,average='micro')
			conf_matrix = confusion_matrix(test_labels, test_preds)
	return test_accuracy,test_recall,test_f1score,test_precision,conf_matrix

# %%
from sklearn.manifold import TSNE
import numpy as np
def extract_features(model, data_loader):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    features = []
    labels = []
    with torch.no_grad():
        for images, labels_batch in data_loader:
            images = images.to(device)
            labels.extend(labels_batch.numpy())
            outputs = model(images)
            features.extend(outputs.cpu().numpy())
    return np.array(features), np.array(labels)

def plot_tsne(train_features, train_labels, test_features, test_labels, dataset_name):
    tsne = TSNE(n_components=2, random_state=42)
    train_features_tsne = tsne.fit_transform(train_features)
    test_features_tsne = tsne.fit_transform(test_features)

    plt.figure(figsize=(20, 8))

    plt.subplot(1, 2, 1)
    for i in range(len(train_dataset.class_names)):
        plt.scatter(train_features_tsne[train_labels == i, 0], train_features_tsne[train_labels == i, 1], label=f'{train_dataset.class_names[i]} (Train)', marker='o', alpha=0.5)
    plt.title(f't-SNE visualization of Train data')
    plt.legend()

    plt.subplot(1, 2, 2)
    for i in range(len(test_dataset.class_names)):
        plt.scatter(test_features_tsne[test_labels == i, 0], test_features_tsne[test_labels == i, 1], label=f'{test_dataset.class_names[i]} (Test)', marker='x', alpha=0.5)
    plt.title(f't-SNE visualization of Test data')
    plt.legend()

    plt.suptitle(f't-SNE visualization of {dataset_name} data', fontsize=16)
    plt.show()

# %%
train_loss_hyperparameters1={}
train_acc_hyperparameters1={}
val_acc_hyperparameters1={}
learning_rate=0.0001
hyper_parameters={"batch_size":[16,32,64]}
num_epochs=25

for batch_size in hyper_parameters["batch_size"]:
  print('==========')
  print(f'Results of the batch_size={batch_size}')
  train_loader = get_data_loader(train_dataset, batch_size, shuffle=True)
  test_loader = get_data_loader(test_dataset, batch_size, shuffle=True)
  val_loader = get_data_loader(val_dataset, batch_size, shuffle=True)
  model = models.resnet18(pretrained=False)

  num_ftrs = model.fc.in_features
  model.fc = nn.Linear(num_ftrs,20)
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)



  train_loss,train_accuracy,val_accuracy,model,val_loss=train(num_epochs,model,train_loader,val_loader,criterion,optimizer)

  train_loss_hyperparameters1[f"lr{batch_size}"]=train_loss
  train_acc_hyperparameters1[f"lr{batch_size}"]=train_accuracy
  val_acc_hyperparameters1[f"lr{batch_size}"]=val_accuracy


  test_accuracy,test_recall,test_f1score,test_precision,conf_matrix = test(model, test_loader)
  print("Test Accuracy: {:.2f}%".format(test_accuracy*100))
  print("Test Precision:",test_precision)
  print("Test Recall:",test_recall)
  print("Test F1score:",test_f1score)
  print("Confusion Matrix on Test Set:")
  figname = "Confusion_matrix"
  fig, ax = plt.subplots(figsize=(12,12))
  ConfusionMatrixDisplay(conf_matrix).plot(ax=ax)
  plt.show()
# Out:
# ==========
# Results of the batch_size=16
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/25], Loss: 2.2374, Accuracy: 32.98%, Val Loss: 1.6955, Val Accuracy: 48.56%
# Epoch [2/25], Loss: 1.4797, Accuracy: 53.41%, Val Loss: 1.3525, Val Accuracy: 60.08%
# Epoch [3/25], Loss: 1.1569, Accuracy: 66.27%, Val Loss: 1.1600, Val Accuracy: 68.31%
# Epoch [4/25], Loss: 0.8786, Accuracy: 75.86%, Val Loss: 0.8736, Val Accuracy: 76.95%
# Epoch [5/25], Loss: 0.6590, Accuracy: 82.60%, Val Loss: 0.6436, Val Accuracy: 82.72%
# Epoch [6/25], Loss: 0.4857, Accuracy: 88.00%, Val Loss: 0.4626, Val Accuracy: 90.95%
# Epoch [7/25], Loss: 0.3303, Accuracy: 92.90%, Val Loss: 0.4395, Val Accuracy: 91.36%
# Epoch [8/25], Loss: 0.2335, Accuracy: 95.58%, Val Loss: 0.5076, Val Accuracy: 94.65%
# Epoch [9/25], Loss: 0.1877, Accuracy: 96.39%, Val Loss: 0.3465, Val Accuracy: 93.00%
# Epoch [10/25], Loss: 0.1368, Accuracy: 97.77%, Val Loss: 0.3650, Val Accuracy: 95.47%
# Epoch [11/25], Loss: 0.0990, Accuracy: 99.02%, Val Loss: 0.2423, Val Accuracy: 94.65%
# Epoch [12/25], Loss: 0.0870, Accuracy: 98.93%, Val Loss: 0.2407, Val Accuracy: 96.30%
# Epoch [13/25], Loss: 0.0722, Accuracy: 99.38%, Val Loss: 0.2351, Val Accuracy: 96.30%
# Epoch [14/25], Loss: 0.0720, Accuracy: 98.97%, Val Loss: 0.2620, Val Accuracy: 96.30%
# Epoch [15/25], Loss: 0.0491, Accuracy: 99.42%, Val Loss: 0.2209, Val Accuracy: 96.71%
# Epoch [16/25], Loss: 0.0621, Accuracy: 99.51%, Val Loss: 0.2176, Val Accuracy: 96.71%
# Epoch [17/25], Loss: 0.0720, Accuracy: 99.06%, Val Loss: 0.2393, Val Accuracy: 96.71%
# Epoch [18/25], Loss: 0.0499, Accuracy: 99.73%, Val Loss: 0.2287, Val Accuracy: 96.30%
# Epoch [19/25], Loss: 0.0352, Accuracy: 99.82%, Val Loss: 0.2193, Val Accuracy: 97.94%
# Epoch [20/25], Loss: 0.0399, Accuracy: 99.82%, Val Loss: 0.2170, Val Accuracy: 97.53%
# Epoch [21/25], Loss: 0.0500, Accuracy: 99.64%, Val Loss: 0.2153, Val Accuracy: 96.30%
# Epoch [22/25], Loss: 0.0401, Accuracy: 99.73%, Val Loss: 0.2002, Val Accuracy: 97.12%
# Epoch [23/25], Loss: 0.0282, Accuracy: 99.96%, Val Loss: 0.2289, Val Accuracy: 96.71%
# Epoch [24/25], Loss: 0.0430, Accuracy: 99.73%, Val Loss: 0.2206, Val Accuracy: 97.94%
# Epoch [25/25], Loss: 0.0347, Accuracy: 99.87%, Val Loss: 0.2065, Val Accuracy: 97.94%
# Device: cuda:0
# Test Accuracy: 98.57%
# Test Precision: 0.9857369255150554
# Test Recall: 0.9857369255150554
# Test F1score: 0.9857369255150554
# Confusion Matrix on Test Set:
# ==========
# Results of the batch_size=32
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/25], Loss: 2.5123, Accuracy: 25.21%, Val Loss: 2.0902, Val Accuracy: 34.16%
# Epoch [2/25], Loss: 1.8178, Accuracy: 45.56%, Val Loss: 1.6147, Val Accuracy: 49.79%
# Epoch [3/25], Loss: 1.4512, Accuracy: 55.38%, Val Loss: 1.4064, Val Accuracy: 60.08%
# Epoch [4/25], Loss: 1.2435, Accuracy: 61.27%, Val Loss: 1.2395, Val Accuracy: 64.20%
# Epoch [5/25], Loss: 1.0734, Accuracy: 69.21%, Val Loss: 1.4501, Val Accuracy: 53.91%
# Epoch [6/25], Loss: 0.9367, Accuracy: 73.94%, Val Loss: 1.1028, Val Accuracy: 65.84%
# Epoch [7/25], Loss: 0.7880, Accuracy: 78.85%, Val Loss: 0.8898, Val Accuracy: 76.13%
# Epoch [8/25], Loss: 0.6649, Accuracy: 82.15%, Val Loss: 0.9252, Val Accuracy: 75.31%
# Epoch [9/25], Loss: 0.5596, Accuracy: 86.66%, Val Loss: 0.7287, Val Accuracy: 81.89%
# Epoch [10/25], Loss: 0.4603, Accuracy: 88.71%, Val Loss: 0.6143, Val Accuracy: 84.36%
# Epoch [11/25], Loss: 0.4002, Accuracy: 91.39%, Val Loss: 0.6696, Val Accuracy: 82.30%
# Epoch [12/25], Loss: 0.3292, Accuracy: 94.02%, Val Loss: 0.4287, Val Accuracy: 90.53%
# Epoch [13/25], Loss: 0.2664, Accuracy: 95.76%, Val Loss: 0.4766, Val Accuracy: 90.12%
# Epoch [14/25], Loss: 0.2395, Accuracy: 96.30%, Val Loss: 0.4068, Val Accuracy: 93.00%
# Epoch [15/25], Loss: 0.1861, Accuracy: 97.99%, Val Loss: 0.2953, Val Accuracy: 93.83%
# Epoch [16/25], Loss: 0.1643, Accuracy: 98.04%, Val Loss: 0.8236, Val Accuracy: 80.66%
# Epoch [17/25], Loss: 0.1601, Accuracy: 98.04%, Val Loss: 0.2865, Val Accuracy: 95.88%
# Epoch [18/25], Loss: 0.1220, Accuracy: 98.97%, Val Loss: 0.2472, Val Accuracy: 95.88%
# Epoch [19/25], Loss: 0.1083, Accuracy: 99.06%, Val Loss: 0.2917, Val Accuracy: 96.30%
# Epoch [20/25], Loss: 0.1002, Accuracy: 99.46%, Val Loss: 0.2234, Val Accuracy: 96.30%
# Epoch [21/25], Loss: 0.0995, Accuracy: 99.51%, Val Loss: 0.2839, Val Accuracy: 95.88%
# Epoch [22/25], Loss: 0.0861, Accuracy: 99.69%, Val Loss: 0.2405, Val Accuracy: 95.88%
# Epoch [23/25], Loss: 0.0771, Accuracy: 99.60%, Val Loss: 0.2270, Val Accuracy: 97.12%
# Epoch [24/25], Loss: 0.0877, Accuracy: 99.55%, Val Loss: 0.2024, Val Accuracy: 97.12%
# Epoch [25/25], Loss: 0.0992, Accuracy: 99.29%, Val Loss: 0.2365, Val Accuracy: 97.12%
# Device: cuda:0
# Test Accuracy: 98.42%
# Test Precision: 0.9841521394611727
# Test Recall: 0.9841521394611727
# Test F1score: 0.9841521394611727
# Confusion Matrix on Test Set:
# ==========
# Results of the batch_size=64
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/25], Loss: 2.7297, Accuracy: 18.03%, Val Loss: 2.7640, Val Accuracy: 20.99%
# Epoch [2/25], Loss: 2.2551, Accuracy: 30.79%, Val Loss: 2.0061, Val Accuracy: 39.51%
# Epoch [3/25], Loss: 1.8569, Accuracy: 41.41%, Val Loss: 1.7785, Val Accuracy: 42.39%
# Epoch [4/25], Loss: 1.5972, Accuracy: 52.66%, Val Loss: 1.6287, Val Accuracy: 49.79%
# Epoch [5/25], Loss: 1.4360, Accuracy: 56.22%, Val Loss: 1.3824, Val Accuracy: 58.44%
# Epoch [6/25], Loss: 1.3077, Accuracy: 60.73%, Val Loss: 1.5605, Val Accuracy: 52.26%
# Epoch [7/25], Loss: 1.1907, Accuracy: 64.03%, Val Loss: 1.5496, Val Accuracy: 55.14%
# Epoch [8/25], Loss: 1.0787, Accuracy: 70.33%, Val Loss: 1.2766, Val Accuracy: 61.32%
# Epoch [9/25], Loss: 1.0206, Accuracy: 71.49%, Val Loss: 1.1742, Val Accuracy: 64.61%
# Epoch [10/25], Loss: 0.9270, Accuracy: 73.27%, Val Loss: 1.2654, Val Accuracy: 64.20%
# Epoch [11/25], Loss: 0.8561, Accuracy: 76.66%, Val Loss: 0.9589, Val Accuracy: 69.55%
# Epoch [12/25], Loss: 0.8197, Accuracy: 78.71%, Val Loss: 0.9119, Val Accuracy: 77.78%
# Epoch [13/25], Loss: 0.7787, Accuracy: 81.44%, Val Loss: 1.0400, Val Accuracy: 72.84%
# Epoch [14/25], Loss: 0.6783, Accuracy: 84.02%, Val Loss: 0.8853, Val Accuracy: 75.31%
# Epoch [15/25], Loss: 0.6645, Accuracy: 84.74%, Val Loss: 0.8450, Val Accuracy: 77.78%
# Epoch [16/25], Loss: 0.5715, Accuracy: 88.84%, Val Loss: 0.7961, Val Accuracy: 80.25%
# Epoch [17/25], Loss: 0.5564, Accuracy: 88.80%, Val Loss: 0.6553, Val Accuracy: 87.65%
# Epoch [18/25], Loss: 0.4741, Accuracy: 90.14%, Val Loss: 0.7132, Val Accuracy: 78.19%
# Epoch [19/25], Loss: 0.4475, Accuracy: 92.41%, Val Loss: 0.7351, Val Accuracy: 77.37%
# Epoch [20/25], Loss: 0.4448, Accuracy: 91.39%, Val Loss: 0.6244, Val Accuracy: 86.83%
# Epoch [21/25], Loss: 0.3918, Accuracy: 93.84%, Val Loss: 0.7651, Val Accuracy: 80.25%
# Epoch [22/25], Loss: 0.3293, Accuracy: 94.96%, Val Loss: 0.5691, Val Accuracy: 87.24%
# Epoch [23/25], Loss: 0.3259, Accuracy: 94.87%, Val Loss: 0.8196, Val Accuracy: 80.25%
# Epoch [24/25], Loss: 0.2985, Accuracy: 95.45%, Val Loss: 0.6003, Val Accuracy: 85.60%
# Epoch [25/25], Loss: 0.2669, Accuracy: 95.63%, Val Loss: 0.5030, Val Accuracy: 88.89%
# Device: cuda:0
# Test Accuracy: 90.02%
# Test Precision: 0.9001584786053882
# Test Recall: 0.9001584786053882
# Test F1score: 0.9001584786053882
# Confusion Matrix on Test Set:

# %%
train_loss_hyperparameters={}
train_acc_hyperparameters={}
val_acc_hyperparameters={}
batch_size=32
hyper_parameters={"learning_rate":[0.001,0.0001]}
num_epochs=25


for learning_rate in hyper_parameters["learning_rate"]:
  print('==========')
  print(f'Results of the learning rate={learning_rate}')
  train_loader = get_data_loader(train_dataset, batch_size, shuffle=True)
  test_loader = get_data_loader(test_dataset, batch_size, shuffle=True)
  val_loader = get_data_loader(val_dataset, batch_size, shuffle=True)
  model2 = models.resnet18(pretrained=False)

  num_ftrs = model2.fc.in_features
  model2.fc = nn.Linear(num_ftrs,20)
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model2.parameters(), lr=0.001, momentum=0.9)



  train_loss,train_accuracy,val_accuracy,model,val_loss=train(num_epochs,model2,train_loader,val_loader,criterion,optimizer)

  train_loss_hyperparameters[f"lr{learning_rate}"]=train_loss
  train_acc_hyperparameters[f"lr{learning_rate}"]=train_accuracy
  val_acc_hyperparameters[f"lr{learning_rate}"]=val_accuracy


  test_accuracy,test_recall,test_f1score,test_precision,conf_matrix = test(model2, test_loader)
  print("Test Accuracy: {:.2f}%".format(test_accuracy*100))
  print("Test Precision:",test_precision)
  print("Test Recall:",test_recall)
  print("Test F1score:",test_f1score)
# Out:
# ==========
# Results of the learning rate=0.001
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/25], Loss: 2.5681, Accuracy: 24.45%, Val Loss: 2.1382, Val Accuracy: 33.33%
# Epoch [2/25], Loss: 1.7363, Accuracy: 47.03%, Val Loss: 1.5843, Val Accuracy: 50.21%
# Epoch [3/25], Loss: 1.4315, Accuracy: 54.57%, Val Loss: 1.3933, Val Accuracy: 55.14%
# Epoch [4/25], Loss: 1.2318, Accuracy: 62.78%, Val Loss: 1.4545, Val Accuracy: 53.09%
# Epoch [5/25], Loss: 1.1132, Accuracy: 65.77%, Val Loss: 1.0990, Val Accuracy: 72.02%
# Epoch [6/25], Loss: 0.9427, Accuracy: 74.48%, Val Loss: 1.0325, Val Accuracy: 66.26%
# Epoch [7/25], Loss: 0.8273, Accuracy: 78.49%, Val Loss: 0.9126, Val Accuracy: 69.96%
# Epoch [8/25], Loss: 0.6999, Accuracy: 81.66%, Val Loss: 0.7791, Val Accuracy: 76.95%
# Epoch [9/25], Loss: 0.5838, Accuracy: 85.27%, Val Loss: 0.7069, Val Accuracy: 79.84%
# Epoch [10/25], Loss: 0.4853, Accuracy: 89.65%, Val Loss: 0.6136, Val Accuracy: 85.19%
# Epoch [11/25], Loss: 0.4003, Accuracy: 92.24%, Val Loss: 0.5863, Val Accuracy: 87.24%
# Epoch [12/25], Loss: 0.3195, Accuracy: 94.24%, Val Loss: 0.6464, Val Accuracy: 82.72%
# Epoch [13/25], Loss: 0.2425, Accuracy: 95.85%, Val Loss: 0.4048, Val Accuracy: 92.18%
# Epoch [14/25], Loss: 0.2326, Accuracy: 97.19%, Val Loss: 0.4054, Val Accuracy: 93.83%
# Epoch [15/25], Loss: 0.1928, Accuracy: 97.59%, Val Loss: 0.3403, Val Accuracy: 94.24%
# Epoch [16/25], Loss: 0.1581, Accuracy: 98.13%, Val Loss: 0.3258, Val Accuracy: 93.42%
# Epoch [17/25], Loss: 0.1460, Accuracy: 98.30%, Val Loss: 0.3718, Val Accuracy: 92.59%
# Epoch [18/25], Loss: 0.1233, Accuracy: 98.48%, Val Loss: 0.3329, Val Accuracy: 95.06%
# Epoch [19/25], Loss: 0.1265, Accuracy: 98.80%, Val Loss: 0.2664, Val Accuracy: 96.30%
# Epoch [20/25], Loss: 0.1174, Accuracy: 99.15%, Val Loss: 0.2754, Val Accuracy: 94.65%
# Epoch [21/25], Loss: 0.1147, Accuracy: 99.20%, Val Loss: 0.3590, Val Accuracy: 93.83%
# Epoch [22/25], Loss: 0.0834, Accuracy: 99.46%, Val Loss: 0.2641, Val Accuracy: 94.65%
# Epoch [23/25], Loss: 0.0855, Accuracy: 99.51%, Val Loss: 0.2245, Val Accuracy: 97.12%
# Epoch [24/25], Loss: 0.0785, Accuracy: 99.42%, Val Loss: 0.2328, Val Accuracy: 97.53%
# Epoch [25/25], Loss: 0.0843, Accuracy: 99.69%, Val Loss: 0.2782, Val Accuracy: 95.06%
# Device: cuda:0
# Test Accuracy: 96.83%
# Test Precision: 0.9683042789223455
# Test Recall: 0.9683042789223455
# Test F1score: 0.9683042789223455
# ==========
# Results of the learning rate=0.0001
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/25], Loss: 2.5353, Accuracy: 24.99%, Val Loss: 2.0382, Val Accuracy: 37.04%
# Epoch [2/25], Loss: 1.7654, Accuracy: 45.74%, Val Loss: 1.9243, Val Accuracy: 41.56%
# Epoch [3/25], Loss: 1.4241, Accuracy: 56.18%, Val Loss: 1.4561, Val Accuracy: 55.97%
# Epoch [4/25], Loss: 1.1886, Accuracy: 64.21%, Val Loss: 1.2476, Val Accuracy: 66.26%
# Epoch [5/25], Loss: 1.0118, Accuracy: 72.07%, Val Loss: 1.0478, Val Accuracy: 70.78%
# Epoch [6/25], Loss: 0.8466, Accuracy: 77.87%, Val Loss: 1.1912, Val Accuracy: 68.72%
# Epoch [7/25], Loss: 0.7246, Accuracy: 80.99%, Val Loss: 0.9646, Val Accuracy: 71.60%
# Epoch [8/25], Loss: 0.6359, Accuracy: 84.29%, Val Loss: 1.1427, Val Accuracy: 68.72%
# Epoch [9/25], Loss: 0.5098, Accuracy: 88.17%, Val Loss: 1.0878, Val Accuracy: 69.55%
# Epoch [10/25], Loss: 0.4407, Accuracy: 91.43%, Val Loss: 0.6924, Val Accuracy: 83.54%
# Epoch [11/25], Loss: 0.3939, Accuracy: 91.83%, Val Loss: 0.5037, Val Accuracy: 88.48%
# Epoch [12/25], Loss: 0.3135, Accuracy: 94.82%, Val Loss: 0.4574, Val Accuracy: 88.07%
# Epoch [13/25], Loss: 0.2385, Accuracy: 96.79%, Val Loss: 0.3772, Val Accuracy: 93.42%
# Epoch [14/25], Loss: 0.2164, Accuracy: 97.05%, Val Loss: 0.3965, Val Accuracy: 93.00%
# Epoch [15/25], Loss: 0.1739, Accuracy: 98.08%, Val Loss: 0.3817, Val Accuracy: 94.24%
# Epoch [16/25], Loss: 0.1423, Accuracy: 98.35%, Val Loss: 0.2900, Val Accuracy: 95.06%
# Epoch [17/25], Loss: 0.1300, Accuracy: 98.66%, Val Loss: 0.2792, Val Accuracy: 94.65%
# Epoch [18/25], Loss: 0.1433, Accuracy: 98.84%, Val Loss: 0.2406, Val Accuracy: 95.88%
# Epoch [19/25], Loss: 0.0964, Accuracy: 99.15%, Val Loss: 0.3268, Val Accuracy: 93.83%
# Epoch [20/25], Loss: 0.1029, Accuracy: 99.29%, Val Loss: 0.2270, Val Accuracy: 95.88%
# Epoch [21/25], Loss: 0.0870, Accuracy: 99.55%, Val Loss: 0.2260, Val Accuracy: 96.71%
# Epoch [22/25], Loss: 0.0677, Accuracy: 99.78%, Val Loss: 0.2584, Val Accuracy: 95.88%
# Epoch [23/25], Loss: 0.0949, Accuracy: 99.55%, Val Loss: 0.2585, Val Accuracy: 94.24%
# Epoch [24/25], Loss: 0.0877, Accuracy: 99.02%, Val Loss: 0.4395, Val Accuracy: 91.77%
# Epoch [25/25], Loss: 0.0658, Accuracy: 99.78%, Val Loss: 0.2188, Val Accuracy: 96.30%
# Device: cuda:0
# Test Accuracy: 97.94%
# Test Precision: 0.9793977812995246
# Test Recall: 0.9793977812995246
# Test F1score: 0.9793977812995246

# %%
train_loss_hyperparameters2={}
train_acc_hyperparameters2={}
val_acc_hyperparameters2={}
learning_rate=0.0001
hyper_parameters={"loss_function":["neg_log_likelihood","cross_entropy"]}
num_epochs=25
batch_size=32

for loss_function in hyper_parameters["loss_function"]:
  print('==========')
  print(f'Results of the loss_function={loss_function}')
  train_loader = get_data_loader(train_dataset, batch_size, shuffle=True)
  test_loader = get_data_loader(test_dataset, batch_size, shuffle=True)
  val_loader = get_data_loader(val_dataset, batch_size, shuffle=True)
  model1 = models.resnet18(pretrained=False)
  num_ftrs = model1.fc.in_features
  model1.fc = nn.Linear(num_ftrs,20)
  if loss_function=="neg_log_likelihood":
    criterion=nn.NLLLoss()
  elif loss_function=="cross_entropy":
    criterion=nn.CrossEntropyLoss()
  optimizer=torch.optim.SGD(model1.parameters(),lr=learning_rate)
  train_loss,train_accuracy,val_accuracy,model,val_loss=train(num_epochs,model1,train_loader,val_loader,criterion,optimizer)

  train_loss_hyperparameters2[f"lfn{loss_function}"]=train_loss
  train_acc_hyperparameters2[f"lfn{loss_function}"]=train_accuracy
  val_acc_hyperparameters2[f"lfn{loss_function}"]=val_accuracy



  test_accuracy,test_recall,test_f1score,test_precision,conf_matrix = test(model1, test_loader)
  print("Test Accuracy: {:.2f}%".format(test_accuracy*100))
  print("Test Precision:",test_precision)
  print("Test Recall:",test_recall)
  print("Test F1score:",test_f1score)
# Out:
# ==========
# Results of the loss_function=neg_log_likelihood
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/25], Loss: 0.0321, Accuracy: 10.31%, Val Loss: -0.0722, Val Accuracy: 13.99%
# Epoch [2/25], Loss: -0.1345, Accuracy: 14.23%, Val Loss: -0.2407, Val Accuracy: 14.40%
# Epoch [3/25], Loss: -0.3106, Accuracy: 14.68%, Val Loss: -0.3916, Val Accuracy: 14.81%
# Epoch [4/25], Loss: -0.4544, Accuracy: 14.32%, Val Loss: -0.5577, Val Accuracy: 13.99%
# Epoch [5/25], Loss: -0.6507, Accuracy: 14.37%, Val Loss: -0.7298, Val Accuracy: 14.40%
# Epoch [6/25], Loss: -0.8229, Accuracy: 14.32%, Val Loss: -0.9273, Val Accuracy: 14.40%
# Epoch [7/25], Loss: -0.9700, Accuracy: 14.32%, Val Loss: -1.0510, Val Accuracy: 14.40%
# Epoch [8/25], Loss: -1.1547, Accuracy: 14.32%, Val Loss: -1.2859, Val Accuracy: 14.40%
# Epoch [9/25], Loss: -1.3152, Accuracy: 14.32%, Val Loss: -1.4662, Val Accuracy: 14.40%
# Epoch [10/25], Loss: -1.4989, Accuracy: 14.32%, Val Loss: -1.7064, Val Accuracy: 14.40%
# Epoch [11/25], Loss: -1.7130, Accuracy: 14.32%, Val Loss: -1.7834, Val Accuracy: 14.40%
# Epoch [12/25], Loss: -1.8715, Accuracy: 14.32%, Val Loss: -2.0196, Val Accuracy: 14.40%
# Epoch [13/25], Loss: -2.1007, Accuracy: 14.32%, Val Loss: -2.2069, Val Accuracy: 14.40%
# Epoch [14/25], Loss: -2.3005, Accuracy: 14.32%, Val Loss: -2.4282, Val Accuracy: 14.40%
# Epoch [15/25], Loss: -2.4440, Accuracy: 14.32%, Val Loss: -2.6074, Val Accuracy: 14.40%
# Epoch [16/25], Loss: -2.6445, Accuracy: 14.32%, Val Loss: -2.9369, Val Accuracy: 14.40%
# Epoch [17/25], Loss: -2.8513, Accuracy: 14.32%, Val Loss: -3.0242, Val Accuracy: 14.40%
# Epoch [18/25], Loss: -3.0602, Accuracy: 14.32%, Val Loss: -3.4735, Val Accuracy: 14.40%
# Epoch [19/25], Loss: -3.2617, Accuracy: 14.32%, Val Loss: -3.7568, Val Accuracy: 14.40%
# Epoch [20/25], Loss: -3.5774, Accuracy: 14.32%, Val Loss: -3.3819, Val Accuracy: 14.40%
# Epoch [21/25], Loss: -3.7393, Accuracy: 14.32%, Val Loss: -4.0869, Val Accuracy: 14.40%
# Epoch [22/25], Loss: -3.9718, Accuracy: 14.32%, Val Loss: -4.2223, Val Accuracy: 14.40%
# Epoch [23/25], Loss: -4.2744, Accuracy: 14.32%, Val Loss: -4.6638, Val Accuracy: 14.40%
# Epoch [24/25], Loss: -4.6050, Accuracy: 14.32%, Val Loss: -4.9392, Val Accuracy: 14.40%
# Epoch [25/25], Loss: -4.7978, Accuracy: 14.32%, Val Loss: -5.5389, Val Accuracy: 14.40%
# Device: cuda:0
# Test Accuracy: 14.26%
# Test Precision: 0.14263074484944532
# Test Recall: 0.14263074484944532
# Test F1score: 0.14263074484944532
# ==========
# Results of the loss_function=cross_entropy
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch [1/25], Loss: 3.0901, Accuracy: 2.23%, Val Loss: 3.0621, Val Accuracy: 2.88%
# Epoch [2/25], Loss: 3.0078, Accuracy: 4.55%, Val Loss: 3.0254, Val Accuracy: 5.76%
# Epoch [3/25], Loss: 2.9643, Accuracy: 9.24%, Val Loss: 2.9435, Val Accuracy: 16.05%
# Epoch [4/25], Loss: 2.9126, Accuracy: 17.89%, Val Loss: 2.9381, Val Accuracy: 17.28%
# Epoch [5/25], Loss: 2.8750, Accuracy: 19.72%, Val Loss: 2.8962, Val Accuracy: 18.52%
# Epoch [6/25], Loss: 2.8398, Accuracy: 19.46%, Val Loss: 2.8484, Val Accuracy: 18.52%
# Epoch [7/25], Loss: 2.8212, Accuracy: 19.28%, Val Loss: 2.8274, Val Accuracy: 18.52%
# Epoch [8/25], Loss: 2.7824, Accuracy: 19.46%, Val Loss: 2.8026, Val Accuracy: 18.52%
# Epoch [9/25], Loss: 2.7724, Accuracy: 19.46%, Val Loss: 2.7775, Val Accuracy: 18.11%
# Epoch [10/25], Loss: 2.7551, Accuracy: 19.72%, Val Loss: 2.7469, Val Accuracy: 18.52%
# Epoch [11/25], Loss: 2.7152, Accuracy: 19.95%, Val Loss: 2.7481, Val Accuracy: 18.52%
# Epoch [12/25], Loss: 2.6995, Accuracy: 19.81%, Val Loss: 2.7159, Val Accuracy: 18.93%
# Epoch [13/25], Loss: 2.6928, Accuracy: 20.48%, Val Loss: 2.6842, Val Accuracy: 18.93%
# Epoch [14/25], Loss: 2.6816, Accuracy: 20.44%, Val Loss: 2.6668, Val Accuracy: 18.93%
# Epoch [15/25], Loss: 2.6566, Accuracy: 20.88%, Val Loss: 2.6613, Val Accuracy: 19.34%
# Epoch [16/25], Loss: 2.6503, Accuracy: 20.75%, Val Loss: 2.6684, Val Accuracy: 20.58%
# Epoch [17/25], Loss: 2.6353, Accuracy: 21.33%, Val Loss: 2.6285, Val Accuracy: 20.58%
# Epoch [18/25], Loss: 2.6215, Accuracy: 21.51%, Val Loss: 2.6039, Val Accuracy: 20.16%
# Epoch [19/25], Loss: 2.5944, Accuracy: 21.60%, Val Loss: 2.5952, Val Accuracy: 20.99%
# Epoch [20/25], Loss: 2.5926, Accuracy: 22.00%, Val Loss: 2.5945, Val Accuracy: 20.99%
# Epoch [21/25], Loss: 2.5782, Accuracy: 22.58%, Val Loss: 2.5550, Val Accuracy: 20.99%
# Epoch [22/25], Loss: 2.5632, Accuracy: 23.07%, Val Loss: 2.5642, Val Accuracy: 22.22%
# Epoch [23/25], Loss: 2.5354, Accuracy: 23.11%, Val Loss: 2.5377, Val Accuracy: 23.87%
# Epoch [24/25], Loss: 2.5201, Accuracy: 23.65%, Val Loss: 2.5431, Val Accuracy: 23.05%
# Epoch [25/25], Loss: 2.5260, Accuracy: 23.78%, Val Loss: 2.5118, Val Accuracy: 24.69%
# Device: cuda:0
# Test Accuracy: 22.98%
# Test Precision: 0.22979397781299524
# Test Recall: 0.22979397781299524
# Test F1score: 0.22979397781299524

# %%
# !pip install flopper
from flopper import count_flops
# Out:
# Collecting flopper
#   Downloading flopper-0.2.1-py3-none-any.whl (9.1 kB)
# Collecting fvcore>=0.1.5 (from flopper)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.10/dist-packages (from flopper) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore>=0.1.5->flopper) (1.25.2)
# Collecting yacs>=0.1.6 (from fvcore>=0.1.5->flopper)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore>=0.1.5->flopper) (6.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore>=0.1.5->flopper) (4.66.2)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore>=0.1.5->flopper) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore>=0.1.5->flopper) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore>=0.1.5->flopper) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore>=0.1.5->flopper)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->flopper) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->flopper) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->flopper) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->flopper) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->flopper) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->flopper) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8->flopper)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8->flopper)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8->flopper)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8->flopper)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8->flopper)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8->flopper)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8->flopper)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8->flopper)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8->flopper)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8->flopper)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8->flopper)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8->flopper) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->flopper)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Collecting portalocker (from iopath>=0.1.7->fvcore>=0.1.5->flopper)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8->flopper) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8->flopper) (1.3.0)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=8bbff6b1c8566294e8b55bdb64c69c5e9f0f1eea6099ad5faeff85458a9dbabd
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=30349c856184baa205403228340aff47610887f3c4dd9d2e0f78ba41bc1b60d8
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, iopath, nvidia-cusolver-cu12, fvcore, flopper
# Successfully installed flopper-0.2.1 fvcore-0.1.5.post20221221 iopath-0.1.10 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 portalocker-2.8.2 yacs-0.1.8

# %%
#final hyperparameters batch_size = 32, lr = 0.0001, cross entrop loss

train_loss_hyperparameters3={}
train_acc_hyperparameters3={}
val_acc_hyperparameters3={}
val_loss_hyperparameters3={}
learning_rate=0.0001
hyper_parameters={"batch_size":[32]}
num_epochs=25

for batch_size in hyper_parameters["batch_size"]:
  print('==========')
  print(f'Results of the batch_size={batch_size}')
  train_loader = get_data_loader(train_dataset, batch_size, shuffle=True)
  test_loader = get_data_loader(test_dataset, batch_size, shuffle=True)
  val_loader = get_data_loader(val_dataset, batch_size, shuffle=True)
  model4 = models.resnet18(pretrained=False)
  batch = torch.randn(1, 3, 224, 224)
  flops = count_flops(model4, batch)
  print(f"Number of FLOPs: {flops}")
  num_ftrs = model4.fc.in_features
  model4.fc = nn.Linear(num_ftrs,20)
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model4.parameters(), lr=0.001, momentum=0.9)

  train_loss,train_accuracy,val_accuracy,model4,val_loss=train(num_epochs,model4,train_loader,val_loader,criterion,optimizer)

  train_loss_hyperparameters3[f"lr{batch_size}"]=train_loss
  train_acc_hyperparameters3[f"lr{batch_size}"]=train_accuracy
  val_acc_hyperparameters3[f"lr{batch_size}"]=val_accuracy
  val_loss_hyperparameters3[f"lr{batch_size}"]=val_loss

  test_accuracy,test_recall,test_f1score,test_precision,conf_matrix = test(model4, test_loader)
  print("Test Accuracy: {:.2f}%".format(test_accuracy*100))
  print("Test Precision:",test_precision)
  print("Test Recall:",test_recall)
  print("Test F1score:",test_f1score)
  print("Confusion Matrix on Test Set:")
  figname = "Confusion_matrix"
  fig, ax = plt.subplots(figsize=(12,12))
  ConfusionMatrixDisplay(conf_matrix).plot(ax=ax)
  plt.show()
  train_features, train_labels = extract_features(model4, train_loader)
  test_features, test_labels = extract_features(model4, test_loader)
  plot_tsne(train_features, train_labels, test_features, test_labels, "Test and Train")
# Out:
# ==========
# Results of the batch_size=32
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# WARNING:fvcore.nn.jit_analysis:Unsupported operator aten::max_pool2d encountered 1 time(s)
# FLOPs of the model ResNet: 1.83 GFLOPs
# Number of FLOPs: <fvcore.nn.flop_count.FlopCountAnalysis object at 0x7b783d34f340>
# Epoch [1/25], Loss: 2.4969, Accuracy: 25.84%, Val Loss: 2.1564, Val Accuracy: 37.04%
# Epoch [2/25], Loss: 1.7479, Accuracy: 45.56%, Val Loss: 2.1754, Val Accuracy: 41.98%
# Epoch [3/25], Loss: 1.4556, Accuracy: 55.87%, Val Loss: 1.4892, Val Accuracy: 58.44%
# Epoch [4/25], Loss: 1.2542, Accuracy: 62.43%, Val Loss: 1.2608, Val Accuracy: 65.84%
# Epoch [5/25], Loss: 1.0985, Accuracy: 67.29%, Val Loss: 1.2312, Val Accuracy: 64.61%
# Epoch [6/25], Loss: 0.9540, Accuracy: 72.78%, Val Loss: 1.0041, Val Accuracy: 71.19%
# Epoch [7/25], Loss: 0.8101, Accuracy: 78.36%, Val Loss: 0.8811, Val Accuracy: 74.49%
# Epoch [8/25], Loss: 0.6951, Accuracy: 80.99%, Val Loss: 0.9862, Val Accuracy: 76.13%
# Epoch [9/25], Loss: 0.5978, Accuracy: 85.36%, Val Loss: 0.7599, Val Accuracy: 81.89%
# Epoch [10/25], Loss: 0.4887, Accuracy: 89.92%, Val Loss: 0.8374, Val Accuracy: 77.78%
# Epoch [11/25], Loss: 0.3909, Accuracy: 91.97%, Val Loss: 0.8545, Val Accuracy: 80.66%
# Epoch [12/25], Loss: 0.3447, Accuracy: 93.17%, Val Loss: 0.4767, Val Accuracy: 93.42%
# Epoch [13/25], Loss: 0.2705, Accuracy: 94.82%, Val Loss: 0.4956, Val Accuracy: 89.71%
# Epoch [14/25], Loss: 0.2378, Accuracy: 96.25%, Val Loss: 0.5555, Val Accuracy: 86.42%
# Epoch [15/25], Loss: 0.2060, Accuracy: 96.03%, Val Loss: 0.3475, Val Accuracy: 94.65%
# Epoch [16/25], Loss: 0.1772, Accuracy: 97.72%, Val Loss: 0.3041, Val Accuracy: 94.65%
# Epoch [17/25], Loss: 0.1547, Accuracy: 97.90%, Val Loss: 0.3898, Val Accuracy: 93.42%
# Epoch [18/25], Loss: 0.1661, Accuracy: 98.39%, Val Loss: 0.9618, Val Accuracy: 77.78%
# Epoch [19/25], Loss: 0.1270, Accuracy: 98.57%, Val Loss: 0.2957, Val Accuracy: 94.65%
# Epoch [20/25], Loss: 0.1401, Accuracy: 98.71%, Val Loss: 0.2544, Val Accuracy: 95.88%
# Epoch [21/25], Loss: 0.0929, Accuracy: 99.11%, Val Loss: 0.3025, Val Accuracy: 94.24%
# Epoch [22/25], Loss: 0.1138, Accuracy: 99.15%, Val Loss: 0.4426, Val Accuracy: 92.18%
# Epoch [23/25], Loss: 0.0869, Accuracy: 99.29%, Val Loss: 0.2647, Val Accuracy: 97.12%
# Epoch [24/25], Loss: 0.0806, Accuracy: 99.42%, Val Loss: 0.2185, Val Accuracy: 96.71%
# Epoch [25/25], Loss: 0.0851, Accuracy: 99.73%, Val Loss: 0.2355, Val Accuracy: 95.88%
# Device: cuda:0
# Test Accuracy: 98.26%
# Test Precision: 0.9825673534072901
# Test Recall: 0.9825673534072901
# Test F1score: 0.9825673534072901
# Confusion Matrix on Test Set:

# %%
key = f"lr{batch_size}"
if key in train_loss_hyperparameters3 and key in val_acc_hyperparameters3:
    num_epochs_actual = len(train_loss_hyperparameters3[key])
    epochs = list(range(1, num_epochs_actual + 1))
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_loss_hyperparameters3[key], label='Training Loss')
    plt.plot(epochs, val_loss_hyperparameters3[key], label='Validation Loss', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
key = f"lr{batch_size}"
if key in train_loss_hyperparameters3 and key in val_acc_hyperparameters3:
    num_epochs_actual = len(train_loss_hyperparameters3[key])
    epochs = list(range(1, num_epochs_actual + 1))
    plt.figure(figsize=(10, 5))
    for batch_size in hyper_parameters["batch_size"]:
        plt.plot(epochs, train_acc_hyperparameters3[f"lr{batch_size}"], label=f'Train Acc (Batch Size={batch_size})')
        plt.plot(epochs, val_acc_hyperparameters3[f"lr{batch_size}"], label=f'Validation Acc (Batch Size={batch_size})')

    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
